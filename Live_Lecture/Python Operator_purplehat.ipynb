# %% [markdown]
# # Operators

# %% [markdown]
# ![operators.jpg](attachment:operators.jpg)

# %% [markdown]
# # Operators in Python

# %% [markdown]
# In this tutorial, you'll going to learn everything about different types of operators in Python, their syntax and how we can use them with multiple examples.

# %% [markdown]
# ## Operators Introduction
#
# 1. Operators are used to perform operations by using variables on assigned values.
#
# 2. variables are nothing but the temporary containors, where we can store/kept values for.
#
# 3. Python Operators in general are used to perform operations on values and variables. These are standard symbols used for the purpose of logical and arithmetic operations.

# %% [markdown]
#     OPERATORS: Are the special symbols. Eg- + , * , /, etc.
#
#     OPERAND: It is the value on which the operator is applied.
#
# 4. An operator is a character or set of characters that can be used to perform the desired operation on the operands and produce the final result.

# %%
# Operators are used to perform operations by using variables on assigned values.

# arithmetic oprtaors
# print(12+10)
# print(12-10)
# print(12*10)
# print(12/10)
# print(12**10)
# print(12//23)
# print(12%12)


 

# assignment operator

num = 1
print(num)
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
num1 = 10
num1+=12
print(num1)
num1-=1
print(num1)
# Out:
# 22
# 21

# %%
12+10,12-10
# Out:
# (22, 2)

# %%
# operator operation using variable
num = 12
num1 = 10

print(num + num1)
# Out:
# 22

# %%
print(12//23)
print(12%12)
# Out:
# 0
# 0

# %%
12/23, 12//23
# Out:
# (0.5217391304347826, 0)

# %%
10/2, 10//2  , 10%2 # only focus on reminder
# Out:
# (5.0, 5, 0)

# %%
v = 10
c =12

# greater than
print(v > c)
# Out:
# False

# %%
v1 = 100
v2 = 12

# greater than
print(v1 > v2)
# Out:
# True

# %%
print(v1 < v2) # 100 < 12
# Out:
# False

# %%
b = 30
b1 = 31

print(b < b1) # 30 < 31
# Out:
# True

# %% [markdown]
# # Types of Operators
#
#  - Arithmetic operators
#  - Assignment operators
#  - Comparison operators
#  - Logical operators
#  - Identity operators
#  - Membership operators
#  - Bitwise operators

# %% [markdown]
# ## Arithmetic operators

# %% [markdown]
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication, modulus, floor Division, Power....
#
# They are used with the items containing numbers/numeric values to perform various common mathematical operations on variables/values.

# %% [markdown]
# ![arithmetic-operation-in-python.png](attachment:arithmetic-operation-in-python.png)

# %% [markdown]
# # Assignment operators

# %% [markdown]
# Assignment operators are used in Python to assign values to variables.
#
# a = 120 is a simple assignment operator that assigns the value 120 on the right to the variable a on the left.
#
# There are various compound operators in Python like a += 4 that adds to the variable and later assigns the same. It is equivalent to a = a + 4.
#
#
# For example:
#             Assume variable a holds 100 and variable b holds 75, see the below example
#
#             a=100
#
#             b=75

# %% [markdown]
# ![assignment-operator-in-python.png](attachment:assignment-operator-in-python.png)

# %% [markdown]
# ![assignment1.jpg](attachment:assignment1.jpg)

# %%
# your code here for practice

# %% [markdown]
# # Comparison operators

# %% [markdown]
# Comparison operators are used to compare values. It returns either True or False according to the condition.
#
# These operators compare the values on either sides of them and decide the relation among them. They are also called Relational operators.

# %% [markdown]
# ![relational-operator-in-python.png](attachment:relational-operator-in-python.png)

# %% [markdown]
# # Logical operator

# %% [markdown]
# Logical operators perform Logical AND, Logical OR, and Logical NOT operations. It is used to combine conditional statements.

# %% [markdown]
# ![logocal.png](attachment:logocal.png)

# %% [markdown]
# Now we can start the oprator concept

# %%
# Arithmetic operator

# + - * / // % **

# Assignment operator

# comparasion operator

# identity operator

# logical operator

# bitwise operator

# membership operator

# %% [markdown]
# Arithmetic operator
#
# # + - * /

# %%
n  = 10
n1 = 20

add = n+n1
print(add)


print(type(n))
# Out:
# 30
# <class 'int'>

# %%
num1 = 12
num2 = 30
print(num1)
print(num2)

print(type(num1))
print(type(num2))

add = num1+num2
print(add)
# or

print(num1+num2)

# or
30+12

# %% [markdown]
# # If i want ot take inputes from user then....

# %%
# input ------- by using this fumction you guys can take inputs from user

value1 = input("Enter a value1:")
print(type(value1))
# Out:
# Enter a value1:10
# <class 'str'>

# %%
value2 = int(input("Enter a values:"))
print(type(value2))
# Out:
# Enter a values:10
# <class 'int'>

# %%
n = input("enter a number:")
n1 =input("enter a second number:")
# Out:
# enter a number:1
# enter a second number:30

# %% [markdown]
# ### NOTE:
# Input method always retrun string data.
#
#
# Concatenation

# %%
n = input("enter a number:")
n1 =input("enter a second number:")

add1 = n+n1
#print(type(add1))
print(add1)
# Out:
# enter a number:10
# enter a second number:20
# 1020

# %%
n= int(input("enter a number:"))#,int(input("enter a number:"))
n1 = int(input("enter a second number:"))

add2 = n+n1
print(add2)
#print(type(add1))
# Out:
# enter a number:10
# enter a second number:20
# 30

# %%
12+23
# Out:
# 35

# %%
'12'+'23'
# Out:
# '1223'

# %%
"Vikas"+"Rathod"
# Out:
# 'VikasRathod'

# %%
v = "ansh"

# %%
v

# %%
n,n1= int(input("enter a number:")),int(input("enter a number:"))
print("Addition:",n+n1)

# %% [markdown]
# # Substraction

# %%
n,n1= int(input("enter a number:")),int(input("enter a number:"))

print(-n-n1)
print(n-n1)

# %% [markdown]
# # Divesion

# %%
n,n1= int(input("enter a number:")),int(input("enter a number:"))
print(n/n1)
# Out:
# enter a number:12
# enter a number:23
# 0.5217391304347826

# %% [markdown]
# Don’t divide anything by zero (0). see below example

# %%
20/23
# Out:
# 0.8695652173913043

# %%
n = 20
n1 = 23

n/n1
# Out:
# 0.8695652173913043

# %%
num =13
num/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-18-2996e8d7671a> in <module>()
#       1 num =13
# ----> 2 num/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # Important Notes
#
# If you divide any number by 0 then you will be prompted by an error called ZeroDivisionError. Don’t divide anything by zero (0).
#
# The result generated by the division operator will always be floating number (represented in decimal points).
#
# Floor division returns the quotient(answer or result of division) in which the digits after the decimal point are removed. But if one of the operands(dividend and divisor) is negative, then the result is floored, i.e., rounded away from zero(means, towards the negative of infinity).

# %% [markdown]
# # Mulptiplication

# %%
n,n1= int(input("enter a number:")),int(input("enter a number:"))
print(n*n1)
# Out:
# enter a number:5
# enter a number:5
# 25

# %% [markdown]
# # Floor devision(//)

# %%
n,n1= int(input("enter a number:")),int(input("enter a number:"))
print(n/n1)

# %%
n,n1= int(input("enter a number:")),int(input("enter a number:"))
print(n//n1)

# %%
30/23

# %% [markdown]
# # mod operation(%)

# %%
n,n1= int(input("enter a number:")),int(input("enter a number:"))
print(n%n1)

# %%
n,n1= int(input("enter a number:")),int(input("enter a number:"))
print(n/n1)

# %%
w,w1= int(input("enter a number:")),int(input("enter a number:"))
print(n%n1) # wrong variable name taken .. you need to use w and w1

# %%
w,w1= int(input("enter a number:")),int(input("enter a number:"))
print(w%w1)
# Out:
# enter a number:12
# enter a number:23
# 12

# %%
32%13

# %%
32/13

# %%
num1  = 10
num2 = 20
if num1%num2 ==0:
    print("even")
else:
    print("odd")

# %%
10/20

# %%
20%10
# Out:
# 0

# %%
20/10   # division
# Out:
# 2.0

# %%
20%10 # mod remainder
# Out:
# 0

# %%
20//10 # floor div  qotiont
# Out:
# 2

# %% [markdown]
# # Power of (**)

# %%
2**3
# Out:
# 8

# %%
3**3
# Out:
# 27

# %%
2**0.5
# Out:
# 1.4142135623730951

# %%
w,w1= int(input("enter a number:")),int(input("enter a number:"))
print(w**w1)
# Out:
# enter a number:10
# enter a number:20
# 100000000000000000000

# %% [markdown]
# # Comparasion/Relational operator

# %%
# > -- greater 
# < -- smaller
# >= -- greater than of equal too
# <= -- samller than of equal too
# != -- not equal to
# ==  -- equal to

# %% [markdown]
# Important notes
#
# Relational operators are also called comparison operators.
#
# The comparison operator can be used to compare more than two values. For example 5 > 3 < 1 will result in False.
#
# These are also called as relational operators because it compares the value and then decides the relation among them. For example, 5 > 4 the relation is such that 5 is greater than 4 and the answer is True. The relation here is greater.

# %% [markdown]
# # > -- greater

# %%
w = int(input("enter a number:"))
w1 = int(input("enter a number:"))

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:20
# enter a number:10

# %%
print(w > w1)  # 20>10
# Out:
# True

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:10
# enter a number:20

# %%
print(w > w1) # 10 > 20
# Out:
# False

# %% [markdown]
# # < -- smaller  OR less than

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:12
# enter a number:13

# %%
print(w)
# Out:
# 12

# %%
print(w1)
# Out:
# 13

# %%
print(w<w1)  #12<13
# Out:
# True

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:20
# enter a number:10

# %%
print(w<w1) # 20 < 10
# Out:
# False

# %% [markdown]
# #  >= -- greater than of equal too

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:2
# enter a number:3

# %%
print(w >= w1) # 2>=3
# Out:
# False

# %%
print(w <= w1) # 2<=3
# Out:
# True

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:10
# enter a number:10

# %%
print(w >= w1) # 10 >= 10
# Out:
# True

# %%
print(w > w1)
# Out:
# False

# %% [markdown]
# # <= -- samller than of equal too

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:10
# enter a number:20

# %%
print(w<=w1) # 10 <= 20
# Out:
# True

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:10
# enter a number:10

# %%
print(w<=w1) # 10 <= 10
# Out:
# True

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:20
# enter a number:10

# %%
print(w <= w1) # 20 <= 10
# Out:
# False

# %% [markdown]
# # ! = -- not equal to

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:100
# enter a number:100

# %%
print(w!=w1)  100!=100
# Out:
# False

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:10
# enter a number:100

# %%
print(w != w1) 10!=100
# Out:
# True

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:10
# enter a number:11

# %%
print(w != w1)
# Out:
# True

# %% [markdown]
# # ==  -- equal to

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:10
# enter a number:10

# %%
print(w == w1)
# Out:
# True

# %%
w,w1 = int(input("enter a number:")),int(input("enter a number:"))
# Out:
# enter a number:20
# enter a number:200

# %%
print(w == w1)
# Out:
# False

# %% [markdown]
# # identity operator
#
# is , is not

# %% [markdown]
# # IS OPERATOR

# %%
v = 5
v1 = 5

print(v is v1)
# Out:
# True

# %%
v = 5
v1 = 50

print(v is v1)
# Out:
# False

# %%
a = 10
b = 10

print(b is a)
# Out:
# True

# %%
v = 5
v1 = 5
print(v is not v1)
# Out:
# False

# %%
v = 5
v1 = 50

print(v is not v1)
# Out:
# True

# %%
v = 12
v1 = 13
print(v is v1)
# Out:
# False

# %%
num = int(input("enter a number:"))

nm1 = 20


print(nm1 is num) # 20 is 20 are same values --- True
# Out:
# enter a number:20
# True

# %%
num = int(input("enter a number:"))

nm1 = 20

print(nm1 is num) # 20 is 30 not same
# Out:
# enter a number:30
# False

# %% [markdown]
# # IS NOT

# %%
b = 10
b1 = 10

print(b is not b1)
# Out:
# False

# %%
b = 10
b1 = 11

print(b is not b1)
# Out:
# True

# %%
num  = int(input("enter a number:"))

if num is 20:
    print(True)
else:
    print(False)
# Out:
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# enter a number:20
# True
# /tmp/ipykernel_5984/3362129295.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num is 20:

# %%
num  = int(input("enter a number:"))

if num is 20:
    print(True)
else:
    print(False)
# Out:
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# enter a number:30
# False
# /tmp/ipykernel_5984/3362129295.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num is 20:

# %% [markdown]
# # membership operator
# in , not in

# %% [markdown]
# # IN Oprator

# %%
lst  = [1,2,3,40.2,5,"Vikas"]
print(1 in lst)
# Out:
# True

# %%
lst  = [1,2,3,40.2,5,"Vikas"]
print(1  not in lst)
# Out:
# False

# %%
lst  = [1,2,3,40.2,5,"Vikas"]
print(100 in lst)
# Out:
# False

# %%
lst = ["pooja","vishakha","harshda",20,462,2,5,3,6,3,6]

print("shaym" in lst)
# Out:
# False

# %%
lst = ["pooja","vishakha","harshda",20,462,2,5,3,6,3,6]

print("462" in lst)
# Out:
# False

# %%
lst = ["pooja","vishakha","harshda",20,462,2,5,3,6,3,6]

print(462 in lst)
# Out:
# True

# %%
lst = ["pooja","vishakha","harshda",20,462,2,5,3,6,3,6]

print(462  not in lst)
# Out:
# False

# %%
lst = ["pooja","vishakha","harshda",20,462,2,5,3,6,3,6]

print('462'  not in lst)
# Out:
# True

# %%
print("Vikas" in lst)
# Out:
# True

# %%
print("Vik" in lst)
# Out:
# False

# %% [markdown]
# # not in

# %%
lst  = [1,2,3,4,5,"Vikas"]
print(lst)
# Out:
# [1, 2, 3, 4, 5, 'Vikas']

# %%
print("Vikas"  not in lst)
# Out:
# False

# %% [markdown]
# # Assignment operator
#
#  = assign operator
# +=,-=,*=,/=, //= (floor equal to),%=

# %%
var = 12
num = 34
name = "sanket"
surname = "tony"
lst = [2,3,4,2,21,2]

# %%
var = 12
var = var+5
print(var)
# Out:
# 17

# %%
var = 12
var += 10
print(var)
# Out:
# 22

# %%
var
# Out:
# 22

# %%
var = 12
var = var - 10
print(var)
# Out:
# 2

# %%
var = 12
var -= 10
print(var)
# Out:
# 2

# %%
var = 12
var *= 10
print(var)
# Out:
# 120

# %%
var = 12
var = var * 10
print(var)
# Out:
# 120

# %%
var = 12
var = var / 10
print(var)
# Out:
# 1.2

# %%
var = 12
var /= 10
print("Divesion:",var)
# Out:
# Divesion: 1.2

# %%
var = 12
var = var % 10
print(var)
# Out:
# 2

# %%
var = 12
var = var // 10
print(var)
# Out:
# 1

# %%
print(v1)
# Out:
# 13

# %% [markdown]
# # Logical operator
#
# and , or , not

# %% [markdown]
# ![logocal%20operator.jpg](attachment:logocal%20operator.jpg)

# %% [markdown]
# # and

# %%
v = True # 1
v1 = True # 0

print(v and v1)
# Out:
# True

# %%
if True and True:
    print("Welcome")
# Out:
# Welcome

# %%
if 1<2 and 2<1:
    print("both condtion are True")

# %%
if 1<2 or 2<1:
    print("both condtion are True")
# Out:
# both condtion are True

# %%
name1 = "harshada"
name2 = "pooja"

nam3 = "harshada"
nam4 = "pooja"


name1 == nam3  # "harshada"  # "harshada"
# Out:
# True

# %% [markdown]
# # Practice

# %%
name1 == name2  # "harshada"  # "pooja"
# Out:
# False

# %%
x = True
x1 = False

# %%
x & x1   # both are different values
# Out:
# False

# %%
x & x  # True # True
# Out:
# True

# %%
x1 & x # False # True
# Out:
# False

# %%
x1 & x1 # False #False
# Out:
# False

# %%
v = True # 1
v1 = True # 1

print(v and v1)
# Out:
# True

# %%
v = False# 1
v1 = False # 1

print(v and v1)
# Out:
# False

# %% [markdown]
# # or

# %%
x = True
x1 = False

# %%
x or x  # True #  True
# Out:
# True

# %%
x or x1  # True # False
# Out:
# True

# %%
x1 or x1
# Out:
# False

# %%
x1 or x # false # True
# Out:
# True

# %%
v = False
v1 = False

print(v or v1)
# Out:
# False

# %%
v = False
v1 =True

print(v or v1)
# Out:
# True

# %%
v = True
v1 = False

print(v or v1)
# Out:
# True

# %%
v = True
v1 = True

print(v or v1)
# Out:
# True

# %% [markdown]
# # not

# %%
v = False
print(not v)
# Out:
# True

# %%
v = True
print(not v)
# Out:
# False

# %% [markdown]
# # BITWISE OPERATOR

# %%
v = 10 # 1010
v1 = 4 # 0100
print(v&v1)
# Out:
# 0

# %%
x = 10
x1 = 6

print(x&x1)
# Out:
# 2

# %% [markdown]
# Explainition

# %%
# 1010
#   &
# 0100
# ----------
# 0000
# ----> 0

# %%
v = 10 # 1010
v1 = 4 # 0100
print( v|v1)
# Out:
# 14

# %%
x1= 10
x2 = 6
print(x1|x2)
# Out:
# 14

# %% [markdown]
# Explaination

# %%
# 1010
#   |
# 0100
# ----------
# 1110
# ----> 14

# %%
print(bin(4))
# Out:
# 0b100

# %%
0b001
# Out:
# 1

# %%
0b100
# Out:
# 4

# %%
0b0001
# Out:
# 1

# %%
0b001001001
# Out:
# 73

# %% [markdown]
# # Comments in python

# %%
num  =  10  # this is an integer number
num1 = 30

'''
    this is  my first program in python

    I loke to learn python PP

    python programming lang is very easy to learn

    i recomend everyon to start python as first progrerammimg 
'''
# Out:
# '\n    this is  my first program in python\n\n    I loke to learn python PP\n\n    python programming lang is very easy to learn\n\n    i recomend everyon to start python as first progrerammimg \n'

# %%
lst = [1,2,3,4,5,6,7,8]
for i in lst:
    print(i)
    """
    if i ==10:
        print("present")
    else:
        print("you enter a wrong number")"""
else:
    print("Completed")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Completed
